# %%
import sys

sys.path.append('/mnt/sdceph/users/nroy/radmc3d-2.0/python/radmc3dPy')
sys.path.append('/mnt/home/nroy/test/chimes-IGNIS/chimes-driver/ext-lib/pfh_python')

from matplotlib import cm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np
import matplotlib.pyplot as plt
import h5py as h5
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['axes.facecolor']='w'
;
# Out:
# ''

# %%
'''FOLLOWING BLOCKS OF CODE ALL CORRELATE TO m12i''';

# %%
''' READ IN OF DATA, m12i '''


CO_0_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations/0deg/CO_J10/"
CO_48_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations/48deg/CO_J10/"
CO_70_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations/70deg/CO_J10/"
CO_90_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations/90deg/CO_J10/"

CII_0_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/0deg/CII_158mu/"
CII_48_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/48deg/CII_158mu/"
CII_70_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/70deg/CII_158mu/"
CII_90_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/90deg/CII_158mu/"

NII_0_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/0deg/NII_6585A/"
NII_48_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/48deg/NII_6585A/"
NII_70_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/70deg/NII_6585A/"
NII_90_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/90deg/NII_6585A/"

Halpha_0_HI_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/0deg/Halpha/HI/"
Halpha_48_HI_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/48deg/Halpha/HI/"
Halpha_70_HI_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/70deg/Halpha/HI/"
Halpha_90_HI_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/90deg/Halpha/HI/"
Halpha_0_HII_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/0deg/Halpha/HII/"
Halpha_48_HII_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/48deg/Halpha/HII/"
Halpha_70_HII_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/70deg/Halpha/HII/"
Halpha_90_HII_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/90deg/Halpha/HII/"

OII_0_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/0deg/OII_3729A/"
OII_48_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/48deg/OII_3729A/"
OII_70_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/70deg/OII_3729A/"
OII_90_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/90deg/OII_3729A/"

OIII_0_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/0deg/OIII_5007A/"
OIII_48_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/48deg/OIII_5007A/"
OIII_70_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/70deg/OIII_5007A/"
OIII_90_m12i = "/home/jovyan/radmc3d_data/subtract_com_velocity/m12i/60kpc/no-continuum-sources/rotations-corrected/90deg/OIII_5007A/"

CO_list_m12i = [CO_0_m12i, CO_48_m12i, CO_70_m12i, CO_90_m12i]
CII_list_m12i = [CII_0_m12i, CII_48_m12i, CII_70_m12i, CII_90_m12i]
NII_list_m12i = [NII_0_m12i, NII_48_m12i, NII_70_m12i, NII_90_m12i]
Halpha_list_HI_m12i = [Halpha_0_HI_m12i, Halpha_48_HI_m12i, Halpha_70_HI_m12i, Halpha_90_HI_m12i]
Halpha_list_HII_m12i = [Halpha_0_HII_m12i, Halpha_48_HII_m12i, Halpha_70_HII_m12i, Halpha_90_HII_m12i]
OIII_list_m12i = [OIII_0_m12i, OIII_48_m12i, OIII_70_m12i, OIII_90_m12i]
OII_list_m12i = [OII_0_m12i, OII_48_m12i, OII_70_m12i, OII_90_m12i]

# %%
CO_vsigma_m12i = []
for l in CO_list_m12i:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)
    
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["CO_J10"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 

    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/60) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -7:
                numerator[i][j] = 0
                denominator[i][j] = 0       
    '''
 
    
    '''
    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq) 
    '''
   

    CO_vsigma_m12i.append(v_sigma)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_60/4041245531.py in <module>
#       6     file_tot = h5.File(filepath_tot,'r')
#       7
# ----> 8     npix_x = np.shape(file_tot['image_array'][:])[0]
#       9     npix_y = np.shape(file_tot['image_array'][:])[1]
#      10
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/h5py/_hl/dataset.py in __getitem__(self, args, new_dtype)
#     766         if self._fast_read_ok and (new_dtype is None):
#     767             try:
# --> 768                 return self._fast_reader.read(args)
#     769             except TypeError:
#     770                 pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %%
CII_vsigma_m12i = []
for l in CII_list_m12i:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)

    if l == CII_0_m12i: 
        theta = 0
        print("at 0")
    if l == CII_48_m12i: 
        theta = 48
        print("at 48")
    if l == CII_70_m12i: 
        theta = 70
        print("at 70")
    if l == CII_90_m12i: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["CII_158mu"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (1024 * (2*4.26/60))*2
    sh = (1024 * (2*0.4/60))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


        
    CII_vsigma_m12i.append(v_sigma)
print(CII_vsigma_m12i)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [0.9936662583074144, 6.075353881972885, 5.7709144843781335, 3.0777852940782826]

# %%
NII_vsigma_m12i = []
for l in NII_list_m12i:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)

    if l == NII_0_m12i: 
        theta = 0
        print("at 0")
    if l == NII_48_m12i: 
        theta = 48
        print("at 48")
    if l == NII_70_m12i: 
        theta = 70
        print("at 70")
    if l == NII_90_m12i: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["NII_6585A"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (1024 * (2*4.26/60))*2
    sh = (1024 * (2*0.4/60))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


        
    NII_vsigma_m12i.append(v_sigma)
print(NII_vsigma_m12i)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [1.5258716165855553, 7.084370020344965, 6.936439719902165, 5.744193434514964]

# %%
Halpha_vsigma_m12i = []
for l in range(len(Halpha_list_HI_m12i)):
    filepath_tot = Halpha_list_HI_m12i[l] + 'image_tot.hdf5'
    filepath_con = Halpha_list_HI_m12i[l] + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)
    
    filepath_tot_2 = Halpha_list_HII_m12i[l] + 'image_tot.hdf5'
    filepath_con_2 = Halpha_list_HII_m12i[l] + 'image_continuum.hdf5'
    file_con_2 = h5.File(filepath_con,'r')
    file_tot_2 = h5.File(filepath_tot,'r')

    npix_x_2 = np.shape(file_tot_2['image_array'][:])[0]
    npix_y_2 = np.shape(file_tot_2['image_array'][:])[1]

    image_array_2 = file_tot_2['image_array'][:] - file_con_2['image_array'][:]

    image_array_2[image_array_2 < 0] = 0

    frequency_array_2 = 3e8 / (file_tot_2['lambda_array'][:] * 1e-6)

    image_array = image_array + image_array_2
    
    if l == 0: 
        theta = 0
        print("at 0")
    if l == 1: 
        theta = 48
        print("at 48")
    if l == 2: 
        theta = 70
        print("at 70")
    if l == 3: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["Halpha"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (1024 * (2*4.26/60))*2
    sh = (1024 * (2*0.4/60))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


        
    Halpha_vsigma_m12i.append(v_sigma)
print(Halpha_vsigma_m12i)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [1.5976595202583959, 6.179895176832844, 6.384349181219732, 5.441177474547545]

# %%
OIII_vsigma_m12i = []
for l in OIII_list_m12i:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)

    if l == OIII_0_m12i: 
        theta = 0
        print("at 0")
    if l == OIII_48_m12i: 
        theta = 48
        print("at 48")
    if l == OIII_70_m12i: 
        theta = 70
        print("at 70")
    if l == OIII_90_m12i: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["OIII_5007A"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (1024 * (2*4.26/60))*2
    sh = (1024 * (2*0.4/60))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


        
    OIII_vsigma_m12i.append(v_sigma)
print(OIII_vsigma_m12i)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [1.070129727973117, 3.7710065759252163, 4.184841527865078, 3.8816534246224927]

# %%
OII_vsigma_m12i = []
for l in OII_list_m12i:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)

    if l == OII_0_m12i: 
        theta = 0
        print("at 0")
    if l == OII_48_m12i: 
        theta = 48
        print("at 48")
    if l == OII_70_m12i: 
        theta = 70
        print("at 70")
    if l == OII_90_m12i: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["OII_3729A"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (1024 * (2*4.26/60))*2
    sh = (1024 * (2*0.4/60))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


        
    OII_vsigma_m12i.append(v_sigma)
print(OII_vsigma_m12i)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [0.8325458272154024, 1.5386493440474978, 1.634473346349502, 1.9703362008985954]

# %%
'''PRINTING VALUES FOR m12i'''
print("CII:", CII_vsigma_m12i)
print("NII:", NII_vsigma_m12i)
print("OII:", OII_vsigma_m12i)
print("Halpha:", Halpha_vsigma_m12i)
print("OIII:", OIII_vsigma_m12i)
# Out:
# CII: [0.9936662583074144, 6.075353881972885, 5.7709144843781335, 3.0777852940782826]
# NII: [1.5258716165855553, 7.084370020344965, 6.936439719902165, 5.744193434514964]
# OII: [0.8325458272154024, 1.5386493440474978, 1.634473346349502, 1.9703362008985954]
# Halpha: [1.5976595202583959, 6.179895176832844, 6.384349181219732, 5.441177474547545]
# OIII: [1.070129727973117, 3.7710065759252163, 4.184841527865078, 3.8816534246224927]

# %%
'''FOLLOWING BLOCKS OF CODE ALL CORRELATE TO A4-151''';

# %%
''' READ IN OF DATA, A4 '''

CO_0_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations/0deg/CO_J10/"
CO_48_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations/48deg/CO_J10/"
CO_70_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations/70deg/CO_J10/"
CO_90_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations/90deg/CO_J10/"

CII_0_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/0deg/CII_158mu/"
CII_48_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/48deg/CII_158mu/"
CII_70_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/70deg/CII_158mu/"
CII_90_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/90deg/CII_158mu/"

NII_0_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/0deg/NII_6585A/"
NII_48_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/48deg/NII_6585A/"
NII_70_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/70deg/NII_6585A/"
NII_90_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/90deg/NII_6585A/"

Halpha_0_HI_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/0deg/Halpha/HI/"
Halpha_48_HI_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/48deg/Halpha/HI/"
Halpha_70_HI_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/70deg/Halpha/HI/"
Halpha_90_HI_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/90deg/Halpha/HI/"
Halpha_0_HII_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/0deg/Halpha/HII/"
Halpha_48_HII_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/48deg/Halpha/HII/"
Halpha_70_HII_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/70deg/Halpha/HII/"
Halpha_90_HII_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/90deg/Halpha/HII/"

OII_0_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/0deg/OII_3729A/"
OII_48_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/48deg/OII_3729A/"
OII_70_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/70deg/OII_3729A/"
OII_90_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/90deg/OII_3729A/"


OIII_0_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/0deg/OIII_5007A/"
OIII_48_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/48deg/OIII_5007A/"
OIII_70_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/70deg/OIII_5007A/"
OIII_90_A4 = "/home/jovyan/radmc3d_data/subtract_com_velocity/A4_33000_snum151/base_resolution_128/no-continuum-sources/rotations-corrected/90deg/OIII_5007A/"

CO_list_A4 = [CO_0_A4, CO_48_A4, CO_70_A4, CO_90_A4]
CII_list_A4 = [CII_0_A4, CII_48_A4, CII_70_A4, CII_90_A4]
NII_list_A4 = [NII_0_A4, NII_48_A4, NII_70_A4, NII_90_A4]
Halpha_list_HI_A4 = [Halpha_0_HI_A4, Halpha_48_HI_A4, Halpha_70_HI_A4, Halpha_90_HI_A4]
Halpha_list_HII_A4 = [Halpha_0_HII_A4, Halpha_48_HII_A4, Halpha_70_HII_A4, Halpha_90_HII_A4]
OIII_list_A4 = [OIII_0_A4, OIII_48_A4, OIII_70_A4, OIII_90_A4]
OII_list_A4 = [OII_0_A4, OII_48_A4, OII_70_A4, OII_90_A4]

# %%
CO_vsigma_A4 = []
for l in CO_list_A4:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)

    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6548A": 0.6545339822769165,
                 "NII_6585A": 0.65807253122329712,
                 "OIII_5007A": 0.50047838687896729, 
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["CO_J10"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -2:
                numerator[i][j] = 0
                denominator[i][j] = 0
    

    
    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)

    CO_vsigma_A4.append(v_sigma)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:70: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:115: RuntimeWarning: divide by zero encountered in log10
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: invalid value encountered in true_divide

# %%
CII_vsigma_A4 = []
for l in CII_list_A4:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)

    if l == CII_0_A4: 
        theta = 0
        print("at 0")
    if l == CII_48_A4: 
        theta = 48
        print("at 48")
    if l == CII_70_A4: 
        theta = 70
        print("at 70")
    if l == CII_90_A4: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["CII_158mu"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (256 * (2*0.82/4))*2
    sh = (256 * (2*0.5/4))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


    CII_vsigma_A4.append(v_sigma)
print(CII_vsigma_A4)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [0.9368944613755211, 1.3727761407257706, 1.58626273848715, 1.6343487866053206]

# %%
NII_vsigma_A4 = []
for l in NII_list_A4:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)

    if l == NII_0_A4: 
        theta = 0
        print("at 0")
    if l == NII_48_A4: 
        theta = 48
        print("at 48")
    if l == NII_70_A4: 
        theta = 70
        print("at 70")
    if l == NII_90_A4: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["NII_6585A"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (256 * (2*0.82/4))*2
    sh = (256 * (2*0.5/4))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


    NII_vsigma_A4.append(v_sigma)
print(NII_vsigma_A4)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [3.195333175820507, 3.255343622776699, 3.059317664662062, 3.575778518859051]

# %%
Halpha_vsigma_A4 = []
for l in range(len(Halpha_list_HI_A4)):
    filepath_tot = Halpha_list_HI_A4[l] + 'image_tot.hdf5'
    filepath_con = Halpha_list_HI_A4[l] + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)
    
    
    filepath_tot_2 = Halpha_list_HII_A4[l] + 'image_tot.hdf5'
    filepath_con_2 = Halpha_list_HII_A4[l] + 'image_continuum.hdf5'
    file_con_2 = h5.File(filepath_con,'r')
    file_tot_2 = h5.File(filepath_tot,'r')

    npix_x_2 = np.shape(file_tot_2['image_array'][:])[0]
    npix_y_2 = np.shape(file_tot_2['image_array'][:])[1]

    image_array_2 = file_tot_2['image_array'][:] - file_con_2['image_array'][:]

    image_array_2[image_array_2 < 0] = 0

    frequency_array_2 = 3e8 / (file_tot_2['lambda_array'][:] * 1e-6)

    image_array = image_array + image_array_2
    if l == 0: 
        theta = 0
        print("at 0")
    if l == 1: 
        theta = 48
        print("at 48")
    if l == 2: 
        theta = 70
        print("at 70")
    if l == 3: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["Halpha"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (256 * (2*0.82/4))*2
    sh = (256 * (2*0.5/4))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


    Halpha_vsigma_A4.append(v_sigma)
print(Halpha_vsigma_A4)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:77: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:99: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [2.0716088364946086, 4.046668240551534, 4.01745916922226, 4.397310900586439]

# %%
OIII_vsigma_A4 = []
for l in OIII_list_A4:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)

    if l == OIII_0_A4: 
        theta = 0
        print("at 0")
    if l == OIII_48_A4: 
        theta = 48
        print("at 48")
    if l == OIII_70_A4: 
        theta = 70
        print("at 70")
    if l == OIII_90_A4: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["OIII_5007A"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (256 * (2*0.82/4))*2
    sh = (256 * (2*0.5/4))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


    OIII_vsigma_A4.append(v_sigma)
print(OIII_vsigma_A4)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [1.5985530093192446, 2.1072766445028224, 2.2060154678146846, 2.411497970589749]

# %%
OII_vsigma_A4 = []
for l in OII_list_A4:
    filepath_tot = l + 'image_tot.hdf5'
    filepath_con = l + 'image_continuum.hdf5'
    file_con = h5.File(filepath_con,'r')
    file_tot = h5.File(filepath_tot,'r')

    npix_x = np.shape(file_tot['image_array'][:])[0]
    npix_y = np.shape(file_tot['image_array'][:])[1]

    image_array = file_tot['image_array'][:] - file_con['image_array'][:]

    image_array[image_array < 0] = 0

    frequency_array = 3e8 / (file_tot['lambda_array'][:] * 1e-6)

    if l == OII_0_A4: 
        theta = 0
        print("at 0")
    if l == OII_48_A4: 
        theta = 48
        print("at 48")
    if l == OII_70_A4: 
        theta = 70
        print("at 70")
    if l == OII_90_A4: 
        theta = 90
        print("at 90")
        
    #moment 0
    integrated_image_array_moment0 = np.zeros((npix_x, npix_y))
    delta_nu = np.abs(frequency_array[1:] - frequency_array[:-1])
    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment0[i, j] = np.sum(delta_nu * (image_array[i, j, :-1] + image_array[i, j, 1:]) / 2.0)

    integrated_image_array_moment0[0,0] = 0 #final moment 0 array
    moment_0 = np.asarray(integrated_image_array_moment0) 

    #moment 1
    lambda_0_dict = {"Halpha": 0.65600490570068359, 
                 "CII_158mu": 157.62730407714844, 
                 "NII_6585A": 0.65807253122329712, 
                 "OIII_5007A": 0.50047838687896729, 
                 "OII_3729A": 0.37272796727,
                 "CO_J10": 2600.757634}

    lambda_0 = lambda_0_dict["OII_3729A"]
    lambda_array = np.array(file_con['lambda_array'])
    velocity_arr = (lambda_array - lambda_0) * 3e5 / lambda_array 


    moment1_noint = velocity_arr * image_array

    integrated_image_array_moment1 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment1[i, j] = np.sum(delta_nu * (moment1_noint[i, j, :-1] + moment1_noint[i, j, 1:]) / 2.0)

    isolate_moment_1 = integrated_image_array_moment1 / integrated_image_array_moment0
    isolate_moment_1[0,0] = 0 #final moment 1 array
    moment_1 = np.asarray(isolate_moment_1) 

    #moment 2
    isolate_moment_1_3D = np.empty([len(image_array), len(image_array), len(velocity_arr)])

    for i in range(len(velocity_arr)):
        for j in range(len(image_array)):
            for k in range(len(image_array)):
                isolate_moment_1_3D[j][k][i] = isolate_moment_1[j][k]

    moment2_noint = image_array * ((velocity_arr - isolate_moment_1_3D) * (velocity_arr - isolate_moment_1_3D))

    integrated_image_array_moment2 = np.zeros((npix_x, npix_y))

    for i in range(npix_x):
        for j in range(npix_y):
            integrated_image_array_moment2[i, j] = np.sum(delta_nu * (moment2_noint[i, j, :-1] + moment2_noint[i, j, 1:]) / 2.0)

    integrated_image_array_moment2[0,0] = 0

    isolate_moment_2 = integrated_image_array_moment2 / integrated_image_array_moment0
    isolate_moment_2[0,0] = 0

    isolate_moment_2 = np.sqrt(isolate_moment_2) #final moment 2 array
    moment_2 = np.asarray(isolate_moment_2) 
    
    #v/sigma
    numerator = moment_0 * ((moment_1)*(moment_1))
    denominator = moment_0 * ((moment_2)*(moment_2))

    #NaN Catcher
    if np.isnan(np.sum(numerator)):
        numerator[np.where(np.isnan(numerator))] = 0
    if np.isnan(np.sum(denominator)):
        denominator[np.where(np.isnan(denominator))] = 0
        
    r = (256 * (2*0.82/4))*2
    sh = (256 * (2*0.5/4))*2
    if theta == 0:
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = i - midpointx
                y = j - midpointy
                dist = np.sqrt(x**2 + y**2)
                if dist > r:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 48 or theta == 70:
        theta = theta * (np.pi/180)
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                # find distance of i and j from center
                x_i = i - midpointx
                y_j = j - midpointy
                dist_ij = np.sqrt(x_i**2 + y_j**2)
                # find angle of line for some i and j 
                working_angle = np.arctan2(y_j, x_i)
                # find distance of ellipse edge from center for that angle
                dist_e = ((r**2)*np.cos(theta))/(np.sqrt(((r*np.cos(theta)*np.cos(working_angle))**2)+((r*np.sin(working_angle))**2)))
                # determine if distance of i and j is greater than distance of ellipse at that angle
                if dist_ij > dist_e:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    if theta == 90: 
        midpointx = len(numerator) / 2
        midpointy = len(numerator[0]) / 2
        for i in range(len(numerator)):
            for j in range(len(numerator[i])):
                x = np.abs(i - midpointx)
                y = np.abs(j - midpointy)
                if x > r or y > sh:
                    numerator[i][j] = 0
                    denominator[i][j] = 0
    

    '''
    #Half Mass Radius
    r = 256 * (2*4.26/10) #m12i
    r = 256 * (2*0.82/4) #A4-151
    tolerance = 1 # CHANGE depending on accuracy we want
    midpointx = len(numerator) / 2
    midpointy = len(numerator[0]) / 2

    half_num = []
    half_denom = [] 
    for i in range(len(numerator)):
        for j in range(len(numerator[i])): 
            x = i - midpointx
            y = j - midpointy
            dist = np.sqrt(x**2 + y**2)
            if dist <= r:
                half_num.append(numerator[i][j])
                half_denom.append(denominator[i][j])    

    # if half mass is true
    v_sigma_sq = (np.sum(half_num))/(np.sum(half_denom))
    v_sigma = np.sqrt(v_sigma_sq)
    '''
    
    '''
    # Low Intensity Mask
    for i in range(len(moment_0)):
        for j in range(len(moment_0[i])):
            if np.log10(moment_0[i][j]/np.max(moment_0)) < -6:
                numerator[i][j] = 0
                denominator[i][j] = 0    
    '''

    # if half mass is false
    v_sigma_sq = (np.sum(numerator))/(np.sum(denominator))
    v_sigma = np.sqrt(v_sigma_sq)    


    OII_vsigma_A4.append(v_sigma)
print(OII_vsigma_A4)
# Out:
# at 0
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in true_divide
# at 48
# at 70
# at 90
# [1.3738965468462985, 1.3308356416034832, 1.32789868679499, 1.2630337968636327]

# %%
'''PRINTING VALUES FOR A4'''
print("CII:", CII_vsigma_A4)
print("NII:", NII_vsigma_A4)
print("OII:", OII_vsigma_A4)
print("Halpha:", Halpha_vsigma_A4)
print("OIII:", OIII_vsigma_A4)
# Out:
# CII: [0.9368944613755211, 1.3727761407257706, 1.58626273848715, 1.6343487866053206]
# NII: [3.195333175820507, 3.255343622776699, 3.059317664662062, 3.575778518859051]
# OII: [1.3738965468462985, 1.3308356416034832, 1.32789868679499, 1.2630337968636327]
# Halpha: [2.0716088364946086, 4.046668240551534, 4.01745916922226, 4.397310900586439]
# OIII: [1.5985530093192446, 2.1072766445028224, 2.2060154678146846, 2.411497970589749]

# %%
'''PLOTTING V/SIGMA VS INCLINATION FOR m12i AND A4'''

#CO_vsigma_m12i = [1.3677359978000982, 7.088776735691009, 7.06598212696002, 3.2264281306813865]
#CII_vsigma_m12i = [1.030532378094604, 6.324446343554477, 6.022586576548603, 3.161771596738486]
#NII_vsigma_m12i = [1.4292998117115698, 3.110381399153076, 6.102881671310464, 5.028572724969167]
#Halpha_vsigma_m12i = [1.5275034646012813, 5.946100749419015, 6.250521137508439, 5.5452161262310895]
#OIII_vsigma_m12i = [1.0682260142450701, 3.8063788113426718, 4.212364681592697, 3.927106725692534]

#CO_vsigma_A4 = [1.5887432511387525, 1.569087729448239, 1.9212353747825206, 2.1044024283630134]
#CII_vsigma_A4 = [0.9271811680619847, 1.3611703117178482, 1.5647105909472256, 1.6244884644245055]
#NII_vsigma_A4 = [2.9935529144012674, 2.9298548354964677, 2.9025720920748967, 3.480087991213445]
#Halpha_vsigma_A4 = [2.3940357692704293, 4.530718913640844, 4.9003860047719385, 5.480521129285457]
#OIII_vsigma_A4 = [1.5984986564132846, 2.0301834175213003, 2.142563717938361, 2.4359338941719373]
'''
m12i with intensity mask
CO: [1.3677368855367769, 7.088779227065451, 7.065983278957972, 3.2264279383524084]
CII: [1.0304797999482582, 6.324471497565011, 6.022608304137122, 3.1617660075744736]
NII: [1.429299812067959, 3.1103817204447886, 6.102881699078426, 5.028572734725566]
Halpha: [1.5318629565130504, 5.96261822405248, 6.265507377722534, 5.562804299478005]
OIII: [1.0669330747500572, 3.8080356883030806, 4.2142415565718565, 3.9354669689612383]

A4 with intensity mask
CO: [1.586630927892245, 1.5543905775538274, 1.909012365594924, 2.0994850768059816]
CII: [0.9079021051665324, 1.341274016016508, 1.5485571395452649, 1.6136125289409387]
NII: [3.5473562533254834, 2.9416027768241393, 2.90072458438549, 3.482581346224478]
Halpha: [2.3949807243502668, 4.532209281105394, 4.901669156733136, 5.4866850024490015]
OIII: [1.5992121911546406, 2.026138887603083, 2.132276454428246, 2.434960873059559]
'''


#m12i with half-mass ellipse mask
CII_vsigma_m12i= [0.9936662583074144, 6.075353881972885, 5.7709144843781335, 3.0777852940782826]
NII_vsigma_m12i= [1.5258716165855553, 7.084370020344965, 6.936439719902165, 5.744193434514964]
OII_vsigma_m12i= [0.8325458272154024, 1.5386493440474978, 1.634473346349502, 1.9703362008985954]
Halpha_vsigma_m12i= [1.5976595202583959, 6.179895176832844, 6.384349181219732, 5.441177474547545]
OIII_vsigma_m12i= [1.070129727973117, 3.7710065759252163, 4.184841527865078, 3.8816534246224927]

#A4 with half-mass ellipse mask
CII_vsigma_A4 = [0.9368944613755211, 1.3727761407257706, 1.58626273848715, 1.6343487866053206]
NII_vsigma_A4 = [3.195333175820507, 3.255343622776699, 3.059317664662062, 3.575778518859051]
OII_vsigma_A4 = [1.3738965468462985, 1.3308356416034832, 1.32789868679499, 1.2630337968636327]
Halpha_vsigma_A4 = [2.0716088364946086, 4.046668240551534, 4.01745916922226, 4.397310900586439]
OIII_vsigma_A4 = [1.5985530093192446, 2.1072766445028224, 2.2060154678146846, 2.411497970589749]



incs = [0, 48, 70, 90]

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(8, 8))

#A4
ax2.plot(incs, CII_vsigma_A4, linestyle = "-", color = "red")
ax2.plot(incs, NII_vsigma_A4, linestyle = "-", color = "orange")
#ax2.plot(incs, OII_vsigma_A4, linestyle = "-", color = "green")
ax2.plot(incs, Halpha_vsigma_A4, linestyle = "-", color = "blue")
ax2.plot(incs, OIII_vsigma_A4, linestyle = "-", color = "purple")


#m12i
ax1.plot(incs, CII_vsigma_m12i, label = r"$[CII]_{158{\mu}m}$", color = "red")
ax1.plot(incs, NII_vsigma_m12i, label = r"$[NII]_{6585A}$", color = "orange")
#ax1.plot(incs, OII_vsigma_m12i, label = r"$[OII]_{3729A}$", color = "green")
ax1.plot(incs, Halpha_vsigma_m12i, label = r"$H{\alpha}$", color = "blue")
ax1.plot(incs, OIII_vsigma_m12i, label = r"$[OIII]_{5007A}$", color = "purple")


plt.xlabel("Inclination Angle (°)", fontsize = 20)
ax1.set_ylabel("V/$\sigma$ - m12i", fontsize = 20)
ax2.set_ylabel("V/$\sigma$ - A4-151", fontsize = 20)

ax1.tick_params(axis='both', which='major', labelsize=15)  # Increase font size
ax2.tick_params(axis='both', which='major', labelsize=15)  # Increase font size

'''
ax1.xticks(fontsize = 15)
ax2.xticks(fontsize = 15)
ax1.yticks(fontsize = 15)
ax2.yticks(fontsize = 15)
'''

ax1.legend(fontsize = 12)

plt.tight_layout()
plt.savefig('vsigma_vs_inc_doubleplot_haldmassellipse_mask_NOOII.pdf', bbox_inches='tight', pad_inches = 0)
plt.show()
